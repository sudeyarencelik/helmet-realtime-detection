# %% [markdown]
# # YOLOv8 Sonuçları

# %%
from ultralytics import YOLO
from PIL import Image

# %%
model = YOLO("yolov8n.pt")

# %%
Image.open("runs/detect/train-3/results.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 Image.open("runs/detect/train-3/results.png")
#
# NameError: name 'Image' is not defined

# %%
Image.open("runs/detect/train-3/confusion_matrix.png")

# %% [markdown]
# # YOLO11 Eğitimi

# %%
model = YOLO("yolo11n.pt")

# %%
results = model.train(
    data="halmet_dataset/data.yaml",
    epochs=100,
    imgsz=640,
    device=0,
    workers=0,
    name="yolo11_final"
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.92 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.89  Python-3.11.9 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...

# %% [markdown]
# # YOLO11 Sonuçları

# %%
from PIL import Image

Image.open("runs/detect/yolo11_final/results.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2400x1200>

# %%
Image.open("runs/detect/yolo11_final/confusion_matrix.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=3000x2250>

# %%
Image.open("runs/detect/yolo11_final/BoxPR_curve.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2250x1500>

# %%
import pandas as pd

df = pd.read_csv("runs/detect/yolo11-2/results.csv")
df.tail()
# Out:
#     epoch     time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 95     96  14916.6         1.26520         0.54867         1.07179
# 96     97  15029.0         1.26414         0.54770         1.07215
# 97     98  15141.9         1.26147         0.54676         1.07020
# 98     99  15254.6         1.26206         0.54259         1.07157
# 99    100  15367.2         1.25326         0.54390         1.06267
#
#     metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 95               0.27858            0.81467           0.27289
# 96               0.27983            0.81687           0.27368
# 97               0.27796            0.82894           0.27284
# 98               0.27839            0.83076           0.27228
# 99               0.27825            0.82519           0.27225
#
#     metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 95              0.14742       1.29047       169.708       0.96361  0.000099
# ...

# %% [markdown]
# # YOLOv26 Eğitimi

# %%
model = YOLO("yolo26n.pt")

# %%
results = model.train(
    data="halmet_dataset/data.yaml",
    epochs=100,
    imgsz=640,
    device=0,
    workers=0,
    name="yolo26"
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.93 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.89  Python-3.11.9 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...

# %%
from PIL import Image

Image.open("runs/detect/yolo26/results.png")

# %%
Image.open("runs/detect/yolo26/confusion_matrix.png")

# %%
Image.open("runs/detect/yolo26/confusion_matrix_normalized.png")

# %%
Image.open("runs/detect/yolo26/BoxPR_curve.png")

# %%
Image.open("runs/detect/yolo26/BoxR_curve.png")

# %%
runs/detect/yolo26/
